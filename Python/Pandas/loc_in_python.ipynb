# %%
import pandas as pd
data={"state":["UP","MP","Maharastra","Rajasthan","Pune","Patna"],
      "year":[2022,2021,2000,2024,2056,2080],
      "pop":[1.4,3.5,2.3,1.3,7.5,8.2]
      }
new_data=pd.DataFrame(data)

# %%
new_data
# Out:
#         state  year  pop
# 0          UP  2022  1.4
# 1          MP  2021  3.5
# 2  Maharastra  2000  2.3
# 3   Rajasthan  2024  1.3
# 4        Pune  2056  7.5
# 5       Patna  2080  8.2

# %%
new_data.set_index('state',inplace=True)

# %%
new_data.loc['MP']
# Out:
# year    2021.0
# pop        3.5
# Name: MP, dtype: float64

# %%
new_data.loc['UP':'Patna']
# Out:
#             year  pop
# state
# UP          2022  1.4
# MP          2021  3.5
# Maharastra  2000  2.3
# Rajasthan   2024  1.3
# Pune        2056  7.5
# Patna       2080  8.2

# %%
new_data.loc['UP':'Patna':2]
# Out:
#             year  pop
# state
# UP          2022  1.4
# Maharastra  2000  2.3
# Pune        2056  7.5

# %%
#Fancy indexing
new_data.loc[['MP','Patna']]
# Out:
#        year  pop
# state
# MP     2021  3.5
# Patna  2080  8.2

# %%
new_data.iloc[(new_data['MP'].index)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mohds\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
values={"state":["UP","MP","Maharastra","Rajasthan","Pune","Patna"],
      "year":[2022,2021,2000,2024,2056,2080],
      "pop":[1.4,3.5,2.3,1.3,7.5,8.2]
      }
data2=pd.DataFrame(values)

# %%
indi=data2.index[data2['state']=='UP']
indi
# Out:
# Index(['A'], dtype='object')

# %%
data2.index=['A','B','C','D','E','F']
data2
# Out:
#         state  year  pop
# A          UP  2022  1.4
# B          MP  2021  3.5
# C  Maharastra  2000  2.3
# D   Rajasthan  2024  1.3
# E        Pune  2056  7.5
# F       Patna  2080  8.2

# %%
indice=data2.index[data2['pop']>2].tolist() #Finding index based on condition

# %%
data2
# Out:
#         state  year  pop
# A          UP  2022  1.4
# B          MP  2021  3.5
# C  Maharastra  2000  2.3
# D   Rajasthan  2024  1.3
# E        Pune  2056  7.5
# F       Patna  2080  8.2

# %%
data2.loc['A':'D']
# Out:
#         state  year  pop
# A          UP  2022  1.4
# B          MP  2021  3.5
# C  Maharastra  2000  2.3
# D   Rajasthan  2024  1.3
