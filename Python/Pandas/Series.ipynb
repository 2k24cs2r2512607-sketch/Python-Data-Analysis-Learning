# %%
import pandas as pd
country=["Inida","China","Japan","USA","Europe"]
data=pd.Series(country)
print(data)
print(type(data))
# Pandas identifies string data type as object
# Out:
# 0     Inida
# 1     China
# 2     Japan
# 3       USA
# 4    Europe
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data.values
# Out:
# array(['Inida', 'China', 'Japan', 'USA', 'Europe'], dtype=object)

# %%
marks=[23,45,12,34,67,65]
Subject=["Chemistry","Physics","Math","Hindi","SST","Biology"]
TT=pd.Series(marks,index=Subject,name='CS2E marks')
TT
# Series name is CS2E marks
# TT is a Reference Variable
# Out:
# Chemistry    23
# Physics      45
# Math         12
# Hindi        34
# SST          67
# Biology      65
# Name: CS2E marks, dtype: int64

# %%
TT.index
# Out:
# Index(['Chemistry', 'Hindi', 'Math', 'Hindi', 'SST', 'Biology'], dtype='object')

# %%
TT.values
# Out:
# array([23, 45, 12, 34, 67, 65])

# %%
TT.sort_values()
# Out:
# Math         12
# Chemistry    23
# Hindi        34
# Hindi        45
# Biology      65
# SST          67
# dtype: int64

# %%
TT.median()
# Out:
# np.float64(39.5)

# %%
marks={"Chemistry":23,"Hindi":34,"Math":12,"Physics":22,"SST":11,"Biology":78}
M1=pd.Series(marks)
M1
# Out:
# Chemistry    23
# Hindi        34
# Math         12
# Physics      22
# SST          11
# Biology      78
# dtype: int64
